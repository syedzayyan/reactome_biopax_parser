# %%
# %load_ext autoreload
# %autoreload 2

# %%
from reactome_graphs import ReactomeBioPAX, download_single_biopax_file_by_pathway_id
from pyvis.network import Network
import os
import networkx as nx
from tqdm.auto import tqdm
import hypernetx as hnx
import matplotlib.pyplot as plt

import networkx_temporal as tx

# %%
parser = ReactomeBioPAX()

# %%
parser.parse_biopax3_file("./data/biopax3/R-HSA-168256.xml")

# %%
parser.stoichometry
# Out:
# {'Stoichiometry1': {'stoichiometricCoefficient': '1',
#   'physicalEntity': '#Protein1'},
#  'Stoichiometry2': {'stoichiometricCoefficient': '1',
#   'physicalEntity': '#Protein2'},
#  'Stoichiometry3': {'stoichiometricCoefficient': '1',
#   'physicalEntity': '#Protein3'},
#  'Stoichiometry4': {'stoichiometricCoefficient': '2',
#   'physicalEntity': '#Protein4'},
#  'Stoichiometry5': {'stoichiometricCoefficient': '1',
#   'physicalEntity': '#Protein5'},
#  'Stoichiometry6': {'stoichiometricCoefficient': '1',
#   'physicalEntity': '#Protein6'},
#  'Stoichiometry7': {'stoichiometricCoefficient': '1',
#   'physicalEntity': '#Complex4'},
#  'Stoichiometry8': {'stoichiometricCoefficient': '1',
#   'physicalEntity': '#Protein7'},
#  'Stoichiometry9': {'stoichiometricCoefficient': '1',
#   'physicalEntity': '#Protein11'},
#  'Stoichiometry10': {'stoichiometricCoefficient': '1',
#   'physicalEntity': '#Complex5'},
#  'Stoichiometry11': {'stoichiometricCoefficient': '1',
# ...

# %% [markdown]
# nt = Network('800px', '800px', cdn_resources="remote", notebook=True, directed=True)
# nt.from_nx(G)
# nt.save_graph('./gen_data/nx.html')

# %%
tree
# Out:
# {'Protein1': {'name': 'p-CBP',
#   'aliases': ['p-Y317-PAG1', 'p-PAG1'],
#   'reactome_db_id': '180494',
#   'comment': 'Reactome DB_ID: 180494',
#   'cellularLocation': 'CellularLocationVocabulary1',
#   'complexes': [],
#   'color': 'red'},
#  'Protein2': {'name': 'CSK',
#   'aliases': ['Tyrosine-protein kinase CSK', 'C-Src kinase'],
#   'reactome_db_id': '203776',
#   'comment': 'Reactome DB_ID: 203776',
#   'cellularLocation': 'CellularLocationVocabulary2',
#   'complexes': [],
#   'color': 'red'},
#  'Protein3': {'name': 'CD4',
#   'aliases': [],
#   'reactome_db_id': '167542',
#   'comment': 'Reactome DB_ID: 167542',
#   'cellularLocation': 'CellularLocationVocabulary1',
#   'complexes': [],
#   'color': 'red'},
#  'Protein4': {'name': 'CD247-1',
#   'aliases': ['CD3 zeta (CD3 zeta isoform 1)',
#    'T-cell surface glycoprotein CD3 zeta chain',
#    'CD3Z_HUMAN',
#    'T Cell Receptor zeta chain',
#    'CD247 isoform 1'],
#   'reactome_db_id': '198166',
# ...
